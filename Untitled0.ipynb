# %% [markdown]
# <a href="https://colab.research.google.com/github/efeehs/base_dados_alunos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/efeehs/base_dados_alunos
# Out:
# Cloning into 'base_dados_alunos'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# Receiving objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)

# %%
baseDados = "/content/base_dados_alunos/github - Página1.csv"

with open(baseDados, "r") as arquivo:
  qtd_linhas = arquivo.readlines()

print(len(qtd_linhas))
# Out:
# 53
